# %% [markdown]
# # Modeling & predictions

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, make_scorer
#from sklearn.model_selection import cross_val_score, KFold
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
#from sklearn.pipeline import make_pipeline
from sklearn.linear_model import Lasso
import xgboost as xgb
#from sklearn.utils import resample
from sklearn.metrics import r2_score

# %% [markdown]
# ### Load data

# %%
prep_X_train = pd.read_csv('data/preprocessed_X_train.csv')
prep_X_train_scaled = pd.read_csv('data/preprocessed_X_train_scaled.csv')

prep_y_train = pd.read_csv('data/preprocessed_y_train.csv')

prep_X_test = pd.read_csv('data/preprocessed_X_test.csv')
prep_X_test_scaled = pd.read_csv('data/preprocessed_X_test_scaled.csv')
orig_X_test = pd.read_csv('data/test.csv')

# %% [markdown]
# ### Choose only the features with variability in the values
# i.e. if only few observations with a different value, the feature is not included.
# No a result improving effect.

# %%
#prep_X_train_scaled = prep_X_train_scaled.iloc[:, np.r_[2:11,12:15,16,20,22:30,31]].copy()

#prep_X_test_scaled = prep_X_test_scaled.iloc[:,np.r_[2:11,12:15,16,20,22:30,31]].copy()

# %% [markdown]
# ### Remove rows with high leverage point feature values based on z value
# This one does not have an improving effect either...

# %%
from scipy.stats import zscore

# Compute the Z-scores for each data point
z_scores = zscore(prep_X_train_scaled)

# Define a threshold for Z-scores (e.g., 3 standard deviations)
threshold = 3.5

# Create a boolean mask for outliers: FALSE = outlier
outliers_mask_z = (abs(z_scores) < threshold).all(axis=1)

# Drop rows with at least one outlier
df_no_outliers_z = prep_X_train_scaled[outliers_mask_z]

# Get the indices of the rows without outliers in df_X
indices_no_outliers_z = df_no_outliers_z.index

# Filter df_y based on the indices
df_y_no_outliers_z = prep_y_train.loc[indices_no_outliers_z]

print(prep_X_train_scaled.shape)
print(df_no_outliers_z.shape)
print(df_y_no_outliers_z.shape)
# Out:
# (27147, 23)
# (25048, 23)
# (25048, 1)

# %% [markdown]
# ### XGBoost algorithm tested
#
# No better results than SVR.

# %%
from sklearn.metrics import mean_squared_error

# Assuming you have your features in X_train and continuous labels in y_train
X_train, X_test, y_train, y_test = train_test_split(prep_X_train_scaled, prep_y_train, test_size=0.2, random_state=42)
#X_train, X_test, y_train, y_test = train_test_split(df_no_outliers_z, df_y_no_outliers_z, test_size=0.2, random_state=42) #where high leverage points removed.

# Create DMatrix objects for XGBoost
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)
dtestreal = xgb.DMatrix(prep_X_test_scaled)

# Set XGBoost parameters for regression
params = {
    'objective': 'reg:squarederror',  # Regression task
    'eval_metric': 'rmse',             # Root Mean Squared Error
    'max_depth': 4,
    'learning_rate': 0.1,
    'gamma': 0.1,                       # Regularization parameter
    'subsample': 0.8,                   # Subsample ratio of the training instance
    'colsample_bytree': 0.8,            # Subsample ratio of columns when constructing each tree
    'alpha': 10,                       # L1 regularization term on weights
    'lambda': 0.1                       # L2 regularization term on weights
}

# Train the XGBoost regression model with early stopping
num_rounds = 1000
model = xgb.train(params, dtrain, num_rounds, evals=[(dtest, 'eval')], early_stopping_rounds=20)

# Make predictions on the test set
y_pred = model.predict(dtest)

# Evaluate the model
rmse = mean_squared_error(y_test, y_pred, squared=False)
#print(f"Root Mean Squared Error (RMSE): {rmse}")
r2 = r2_score(y_test, y_pred)
print(f'R^2 Score = {r2:.4f}')

predictions = model.predict(dtestreal)

results = pd.DataFrame()
results['Id'] = orig_X_test['Id']
results['target'] = predictions

results.head()

results.to_csv('data/results.csv', index=False)
# Out:
# [0]	eval-rmse:2.06673
# [1]	eval-rmse:1.95671
# [2]	eval-rmse:1.86181
# [3]	eval-rmse:1.78120
# [4]	eval-rmse:1.70826
# [5]	eval-rmse:1.64681
# [6]	eval-rmse:1.60321
# [7]	eval-rmse:1.56594
# [8]	eval-rmse:1.52073
# [9]	eval-rmse:1.48123
# [10]	eval-rmse:1.45468
# [11]	eval-rmse:1.42597
# [12]	eval-rmse:1.40132
# [13]	eval-rmse:1.38240
# [14]	eval-rmse:1.36647
# [15]	eval-rmse:1.34682
# [16]	eval-rmse:1.33089
# [17]	eval-rmse:1.31719
# [18]	eval-rmse:1.30679
# [19]	eval-rmse:1.29710
# [20]	eval-rmse:1.28837
# [21]	eval-rmse:1.28075
# [22]	eval-rmse:1.27380
# [23]	eval-rmse:1.26573
# [24]	eval-rmse:1.25979
# [25]	eval-rmse:1.25350
# [26]	eval-rmse:1.24879
# [27]	eval-rmse:1.24352
# [28]	eval-rmse:1.23929
# [29]	eval-rmse:1.23476
# [30]	eval-rmse:1.23116
# [31]	eval-rmse:1.22809
# [32]	eval-rmse:1.22446
# [33]	eval-rmse:1.22068
# [34]	eval-rmse:1.21761
# [35]	eval-rmse:1.21496
# [36]	eval-rmse:1.21245
# [37]	eval-rmse:1.20980
# [38]	eval-rmse:1.20789
# [39]	eval-rmse:1.20408
# [40]	eval-rmse:1.20200
# [41]	eval-rmse:1.19976
# [42]	eval-rmse:1.19771
# [43]	eval-rmse:1.19440
# [44]	eval-rmse:1.19252
# [45]	eval-rmse:1.19077
# [46]	eval-rmse:1.18982
# [47]	eval-rmse:1.18876
# [48]	eval-rmse:1.18766
# [49]	eval-rmse:1.18610
# [50]	eval-rmse:1.18374
# [51]	eval-rmse:1.18227
# [52]	eval-rmse:1.18036
# [53]	eval-rmse:1.17913
# [54]	eval-rmse:1.17767
# [55]	eval-rmse:1.17685
# [56]	eval-rmse:1.17561
# [57]	eval-rmse:1.17385
# [58]	eval-rmse:1.17238
# [59]	eval-rmse:1.17165
# [60]	eval-rmse:1.17084
# [61]	eval-rmse:1.16899
# [62]	eval-rmse:1.16853
# [63]	eval-rmse:1.16753
# [64]	eval-rmse:1.16708
# [65]	eval-rmse:1.16645
# [66]	eval-rmse:1.16535
# [67]	eval-rmse:1.16426
# [68]	eval-rmse:1.16387
# [69]	eval-rmse:1.16300
# [70]	eval-rmse:1.16265
# [71]	eval-rmse:1.16201
# [72]	eval-rmse:1.16125
# [73]	eval-rmse:1.15992
# [74]	eval-rmse:1.15942
# [75]	eval-rmse:1.15899
# [76]	eval-rmse:1.15835
# [77]	eval-rmse:1.15748
# [78]	eval-rmse:1.15733
# [79]	eval-rmse:1.15694
# [80]	eval-rmse:1.15595
# [81]	eval-rmse:1.15514
# [82]	eval-rmse:1.15457
# [83]	eval-rmse:1.15422
# [84]	eval-rmse:1.15400
# [85]	eval-rmse:1.15302
# [86]	eval-rmse:1.15273
# [87]	eval-rmse:1.15220
# [88]	eval-rmse:1.15146
# [89]	eval-rmse:1.15135
# [90]	eval-rmse:1.15101
# [91]	eval-rmse:1.14995
# [92]	eval-rmse:1.14968
# [93]	eval-rmse:1.14904
# [94]	eval-rmse:1.14898
# [95]	eval-rmse:1.14832
# [96]	eval-rmse:1.14819
# [97]	eval-rmse:1.14796
# [98]	eval-rmse:1.14734
# [99]	eval-rmse:1.14692
# [100]	eval-rmse:1.14663
# [101]	eval-rmse:1.14598
# [102]	eval-rmse:1.14554
# [103]	eval-rmse:1.14497
# [104]	eval-rmse:1.14457
# [105]	eval-rmse:1.14418
# [106]	eval-rmse:1.14394
# [107]	eval-rmse:1.14379
# [108]	eval-rmse:1.14329
# [109]	eval-rmse:1.14306
# [110]	eval-rmse:1.14288
# [111]	eval-rmse:1.14213
# [112]	eval-rmse:1.14165
# [113]	eval-rmse:1.14147
# [114]	eval-rmse:1.14077
# [115]	eval-rmse:1.14078
# [116]	eval-rmse:1.14057
# [117]	eval-rmse:1.14038
# [118]	eval-rmse:1.14023
# [119]	eval-rmse:1.14023
# [120]	eval-rmse:1.13992
# [121]	eval-rmse:1.13982
# [122]	eval-rmse:1.13981
# [123]	eval-rmse:1.13951
# [124]	eval-rmse:1.13931
# [125]	eval-rmse:1.13900
# [126]	eval-rmse:1.13857
# [127]	eval-rmse:1.13790
# [128]	eval-rmse:1.13779
# [129]	eval-rmse:1.13730
# [130]	eval-rmse:1.13670
# [131]	eval-rmse:1.13641
# [132]	eval-rmse:1.13573
# [133]	eval-rmse:1.13548
# [134]	eval-rmse:1.13528
# [135]	eval-rmse:1.13499
# [136]	eval-rmse:1.13451
# [137]	eval-rmse:1.13424
# [138]	eval-rmse:1.13368
# [139]	eval-rmse:1.13350
# [140]	eval-rmse:1.13342
# [141]	eval-rmse:1.13304
# [142]	eval-rmse:1.13287
# [143]	eval-rmse:1.13255
# [144]	eval-rmse:1.13236
# [145]	eval-rmse:1.13225
# [146]	eval-rmse:1.13226
# [147]	eval-rmse:1.13222
# [148]	eval-rmse:1.13188
# [149]	eval-rmse:1.13174
# [150]	eval-rmse:1.13122
# [151]	eval-rmse:1.13079
# [152]	eval-rmse:1.13106
# [153]	eval-rmse:1.13090
# [154]	eval-rmse:1.13066
# [155]	eval-rmse:1.13053
# [156]	eval-rmse:1.13041
# [157]	eval-rmse:1.13018
# [158]	eval-rmse:1.13000
# [159]	eval-rmse:1.12984
# [160]	eval-rmse:1.12966
# [161]	eval-rmse:1.12955
# [162]	eval-rmse:1.12948
# [163]	eval-rmse:1.12953
# [164]	eval-rmse:1.12942
# [165]	eval-rmse:1.12945
# [166]	eval-rmse:1.12925
# [167]	eval-rmse:1.12934
# [168]	eval-rmse:1.12918
# [169]	eval-rmse:1.12911
# [170]	eval-rmse:1.12916
# [171]	eval-rmse:1.12906
# [172]	eval-rmse:1.12869
# [173]	eval-rmse:1.12877
# [174]	eval-rmse:1.12873
# [175]	eval-rmse:1.12864
# [176]	eval-rmse:1.12850
# [177]	eval-rmse:1.12840
# [178]	eval-rmse:1.12825
# [179]	eval-rmse:1.12824
# [180]	eval-rmse:1.12810
# [181]	eval-rmse:1.12804
# [182]	eval-rmse:1.12784
# [183]	eval-rmse:1.12750
# [184]	eval-rmse:1.12729
# [185]	eval-rmse:1.12759
# [186]	eval-rmse:1.12757
# [187]	eval-rmse:1.12738
# [188]	eval-rmse:1.12752
# [189]	eval-rmse:1.12726
# [190]	eval-rmse:1.12714
# [191]	eval-rmse:1.12694
# [192]	eval-rmse:1.12672
# [193]	eval-rmse:1.12657
# [194]	eval-rmse:1.12638
# [195]	eval-rmse:1.12601
# [196]	eval-rmse:1.12591
# [197]	eval-rmse:1.12565
# [198]	eval-rmse:1.12566
# [199]	eval-rmse:1.12567
# [200]	eval-rmse:1.12544
# [201]	eval-rmse:1.12531
# [202]	eval-rmse:1.12548
# [203]	eval-rmse:1.12529
# [204]	eval-rmse:1.12519
# [205]	eval-rmse:1.12511
# [206]	eval-rmse:1.12526
# [207]	eval-rmse:1.12498
# [208]	eval-rmse:1.12470
# [209]	eval-rmse:1.12428
# [210]	eval-rmse:1.12424
# [211]	eval-rmse:1.12427
# [212]	eval-rmse:1.12423
# [213]	eval-rmse:1.12434
# [214]	eval-rmse:1.12425
# [215]	eval-rmse:1.12417
# [216]	eval-rmse:1.12416
# [217]	eval-rmse:1.12412
# [218]	eval-rmse:1.12402
# [219]	eval-rmse:1.12391
# [220]	eval-rmse:1.12383
# [221]	eval-rmse:1.12320
# [222]	eval-rmse:1.12318
# [223]	eval-rmse:1.12298
# [224]	eval-rmse:1.12297
# [225]	eval-rmse:1.12277
# [226]	eval-rmse:1.12274
# [227]	eval-rmse:1.12247
# [228]	eval-rmse:1.12236
# [229]	eval-rmse:1.12240
# [230]	eval-rmse:1.12241
# [231]	eval-rmse:1.12246
# [232]	eval-rmse:1.12226
# [233]	eval-rmse:1.12224
# [234]	eval-rmse:1.12211
# [235]	eval-rmse:1.12194
# [236]	eval-rmse:1.12176
# [237]	eval-rmse:1.12153
# [238]	eval-rmse:1.12134
# [239]	eval-rmse:1.12132
# [240]	eval-rmse:1.12134
# [241]	eval-rmse:1.12137
# [242]	eval-rmse:1.12141
# [243]	eval-rmse:1.12114
# [244]	eval-rmse:1.12103
# [245]	eval-rmse:1.12092
# [246]	eval-rmse:1.12113
# [247]	eval-rmse:1.12114
# [248]	eval-rmse:1.12104
# [249]	eval-rmse:1.12083
# [250]	eval-rmse:1.12073
# [251]	eval-rmse:1.12066
# [252]	eval-rmse:1.12079
# [253]	eval-rmse:1.12085
# [254]	eval-rmse:1.12068
# [255]	eval-rmse:1.12039
# [256]	eval-rmse:1.12010
# [257]	eval-rmse:1.12018
# [258]	eval-rmse:1.12022
# [259]	eval-rmse:1.12000
# [260]	eval-rmse:1.12003
# [261]	eval-rmse:1.11989
# [262]	eval-rmse:1.11970
# [263]	eval-rmse:1.11969
# [264]	eval-rmse:1.11994
# [265]	eval-rmse:1.12016
# [266]	eval-rmse:1.11999
# [267]	eval-rmse:1.11989
# [268]	eval-rmse:1.11957
# [269]	eval-rmse:1.11952
# [270]	eval-rmse:1.11964
# [271]	eval-rmse:1.11954
# [272]	eval-rmse:1.11950
# [273]	eval-rmse:1.11951
# [274]	eval-rmse:1.11930
# [275]	eval-rmse:1.11927
# [276]	eval-rmse:1.11922
# [277]	eval-rmse:1.11951
# [278]	eval-rmse:1.11937
# [279]	eval-rmse:1.11928
# [280]	eval-rmse:1.11929
# [281]	eval-rmse:1.11950
# [282]	eval-rmse:1.11941
# [283]	eval-rmse:1.11927
# [284]	eval-rmse:1.11924
# [285]	eval-rmse:1.11914
# [286]	eval-rmse:1.11907
# [287]	eval-rmse:1.11900
# [288]	eval-rmse:1.11891
# [289]	eval-rmse:1.11894
# [290]	eval-rmse:1.11894
# [291]	eval-rmse:1.11895
# [292]	eval-rmse:1.11879
# [293]	eval-rmse:1.11883
# [294]	eval-rmse:1.11888
# [295]	eval-rmse:1.11887
# [296]	eval-rmse:1.11864
# [297]	eval-rmse:1.11861
# [298]	eval-rmse:1.11863
# [299]	eval-rmse:1.11854
# [300]	eval-rmse:1.11847
# [301]	eval-rmse:1.11843
# [302]	eval-rmse:1.11835
# [303]	eval-rmse:1.11840
# [304]	eval-rmse:1.11843
# [305]	eval-rmse:1.11837
# [306]	eval-rmse:1.11845
# [307]	eval-rmse:1.11850
# [308]	eval-rmse:1.11845
# [309]	eval-rmse:1.11855
# [310]	eval-rmse:1.11852
# [311]	eval-rmse:1.11846
# [312]	eval-rmse:1.11832
# [313]	eval-rmse:1.11819
# [314]	eval-rmse:1.11819
# [315]	eval-rmse:1.11820
# [316]	eval-rmse:1.11818
# [317]	eval-rmse:1.11810
# [318]	eval-rmse:1.11800
# [319]	eval-rmse:1.11811
# [320]	eval-rmse:1.11803
# [321]	eval-rmse:1.11837
# [322]	eval-rmse:1.11828
# [323]	eval-rmse:1.11827
# [324]	eval-rmse:1.11837
# [325]	eval-rmse:1.11832
# [326]	eval-rmse:1.11811
# [327]	eval-rmse:1.11793
# [328]	eval-rmse:1.11781
# [329]	eval-rmse:1.11779
# [330]	eval-rmse:1.11776
# [331]	eval-rmse:1.11757
# [332]	eval-rmse:1.11742
# [333]	eval-rmse:1.11754
# [334]	eval-rmse:1.11752
# [335]	eval-rmse:1.11754
# [336]	eval-rmse:1.11741
# [337]	eval-rmse:1.11740
# [338]	eval-rmse:1.11731
# [339]	eval-rmse:1.11727
# [340]	eval-rmse:1.11734
# [341]	eval-rmse:1.11735
# [342]	eval-rmse:1.11719
# [343]	eval-rmse:1.11729
# [344]	eval-rmse:1.11739
# [345]	eval-rmse:1.11727
# [346]	eval-rmse:1.11727
# [347]	eval-rmse:1.11716
# [348]	eval-rmse:1.11715
# [349]	eval-rmse:1.11722
# [350]	eval-rmse:1.11710
# [351]	eval-rmse:1.11708
# [352]	eval-rmse:1.11710
# [353]	eval-rmse:1.11727
# [354]	eval-rmse:1.11715
# [355]	eval-rmse:1.11720
# [356]	eval-rmse:1.11711
# [357]	eval-rmse:1.11713
# [358]	eval-rmse:1.11713
# [359]	eval-rmse:1.11709
# [360]	eval-rmse:1.11694
# [361]	eval-rmse:1.11685
# [362]	eval-rmse:1.11688
# [363]	eval-rmse:1.11675
# [364]	eval-rmse:1.11676
# [365]	eval-rmse:1.11672
# [366]	eval-rmse:1.11689
# [367]	eval-rmse:1.11676
# [368]	eval-rmse:1.11669
# [369]	eval-rmse:1.11688
# [370]	eval-rmse:1.11693
# [371]	eval-rmse:1.11694
# [372]	eval-rmse:1.11679
# [373]	eval-rmse:1.11683
# [374]	eval-rmse:1.11679
# [375]	eval-rmse:1.11682
# [376]	eval-rmse:1.11699
# [377]	eval-rmse:1.11684
# [378]	eval-rmse:1.11652
# [379]	eval-rmse:1.11640
# [380]	eval-rmse:1.11631
# [381]	eval-rmse:1.11629
# [382]	eval-rmse:1.11621
# [383]	eval-rmse:1.11614
# [384]	eval-rmse:1.11616
# [385]	eval-rmse:1.11622
# [386]	eval-rmse:1.11646
# [387]	eval-rmse:1.11640
# [388]	eval-rmse:1.11637
# [389]	eval-rmse:1.11648
# [390]	eval-rmse:1.11633
# [391]	eval-rmse:1.11636
# [392]	eval-rmse:1.11640
# [393]	eval-rmse:1.11638
# [394]	eval-rmse:1.11619
# [395]	eval-rmse:1.11625
# [396]	eval-rmse:1.11626
# [397]	eval-rmse:1.11624
# [398]	eval-rmse:1.11606
# [399]	eval-rmse:1.11606
# [400]	eval-rmse:1.11598
# [401]	eval-rmse:1.11598
# [402]	eval-rmse:1.11592
# [403]	eval-rmse:1.11607
# [404]	eval-rmse:1.11596
# [405]	eval-rmse:1.11590
# [406]	eval-rmse:1.11592
# [407]	eval-rmse:1.11580
# [408]	eval-rmse:1.11575
# [409]	eval-rmse:1.11565
# [410]	eval-rmse:1.11566
# [411]	eval-rmse:1.11556
# [412]	eval-rmse:1.11539
# [413]	eval-rmse:1.11545
# [414]	eval-rmse:1.11546
# [415]	eval-rmse:1.11554
# [416]	eval-rmse:1.11557
# [417]	eval-rmse:1.11545
# [418]	eval-rmse:1.11546
# [419]	eval-rmse:1.11577
# [420]	eval-rmse:1.11597
# [421]	eval-rmse:1.11591
# [422]	eval-rmse:1.11592
# [423]	eval-rmse:1.11585
# [424]	eval-rmse:1.11575
# [425]	eval-rmse:1.11577
# [426]	eval-rmse:1.11577
# [427]	eval-rmse:1.11571
# [428]	eval-rmse:1.11564
# [429]	eval-rmse:1.11553
# [430]	eval-rmse:1.11542
# [431]	eval-rmse:1.11538
# [432]	eval-rmse:1.11540
# [433]	eval-rmse:1.11543
# [434]	eval-rmse:1.11527
# [435]	eval-rmse:1.11513
# [436]	eval-rmse:1.11506
# [437]	eval-rmse:1.11500
# [438]	eval-rmse:1.11486
# [439]	eval-rmse:1.11472
# [440]	eval-rmse:1.11465
# [441]	eval-rmse:1.11468
# [442]	eval-rmse:1.11440
# [443]	eval-rmse:1.11438
# [444]	eval-rmse:1.11451
# [445]	eval-rmse:1.11453
# [446]	eval-rmse:1.11467
# [447]	eval-rmse:1.11454
# [448]	eval-rmse:1.11454
# [449]	eval-rmse:1.11471
# [450]	eval-rmse:1.11471
# [451]	eval-rmse:1.11479
# [452]	eval-rmse:1.11496
# [453]	eval-rmse:1.11492
# [454]	eval-rmse:1.11491
# [455]	eval-rmse:1.11485
# [456]	eval-rmse:1.11471
# [457]	eval-rmse:1.11454
# [458]	eval-rmse:1.11458
# [459]	eval-rmse:1.11451
# [460]	eval-rmse:1.11439
# [461]	eval-rmse:1.11446
# [462]	eval-rmse:1.11438
# [463]	eval-rmse:1.11428
# [464]	eval-rmse:1.11442
# [465]	eval-rmse:1.11432
# [466]	eval-rmse:1.11441
# [467]	eval-rmse:1.11441
# [468]	eval-rmse:1.11433
# [469]	eval-rmse:1.11428
# [470]	eval-rmse:1.11447
# [471]	eval-rmse:1.11448
# [472]	eval-rmse:1.11444
# [473]	eval-rmse:1.11437
# [474]	eval-rmse:1.11429
# [475]	eval-rmse:1.11456
# [476]	eval-rmse:1.11456
# [477]	eval-rmse:1.11462
# [478]	eval-rmse:1.11447
# [479]	eval-rmse:1.11434
# [480]	eval-rmse:1.11453
# [481]	eval-rmse:1.11447
# [482]	eval-rmse:1.11442
# [483]	eval-rmse:1.11444
# R^2 Score = 0.7424
